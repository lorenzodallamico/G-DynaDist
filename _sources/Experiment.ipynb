# %% [markdown]
# # Example of usage
#
# In this notebook, we are going to showcase a couple of practical use examples inspired by our [**article**](https://www.nature.com/articles/s41467-024-54280-4).
#
# ## Unmatched distance between graph randomizations
#
# In the first example, we load a proximity graph and generate two families of random graphs obtained by randomizing the time index (see the function `TimeRdn` below) and by randomizing the order in which the snapshots appear (see the function `SequenceRdn` below). For each randomization, we generate $250$ graphs. We then compute a $500 \times 500$ distance matrix between all graph pairs, and we then use this matrix to cluster the graphs according to their randomization class. For simplicity, we visualize the clusters by deploying the `umap` algorithm.
#
# <div style="background-color: #e7f3f9; border-left: 4px solid #2196F3; padding: 12px 16px; border-radius: 6px; font-family: sans-serif; color: #084b63; margin: 1em 0;">
#   <span style="font-weight: bold; display: inline-flex; align-items: center;">
#     <svg style="height: 16px; width: 16px; margin-right: 6px; fill: #084b63;" viewBox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#       <path d="M8 1a7 7 0 100 14A7 7 0 008 1zm.93 10.412c0 .337-.274.588-.61.588h-.64c-.336 0-.61-.251-.61-.588V7.589c0-.337.274-.589.61-.589h.64c.336 0 .61.252.61.589v3.823zM8 5.2a.867.867 0 110-1.734.867.867 0 010 1.733z"/>
#     </svg>
#     Note:
#   </span>
#  The experiment below has a relatively long computation time (~ 12 mins) because we need to generate 500 instances of random temporal graphs, beyond computing the embedding matrices.
# </div>

# %%
import warnings
warnings.filterwarnings('ignore')

# laod packages
import pandas as pd
from copy import copy
import numpy as np
import matplotlib.pyplot as plt
import umap.umap_ as umap

from GDynaDist import Graphs4Distance

# %%
# Define the functions to randomize the temporal graphs
def TimeRdn(df):
        '''With this function, time is randomized by uniformly resampling it between 0 and T, the number of snapshots'''
        df_ = copy(df)
        T = df_.t.max()
        df_.t = np.random.choice(np.arange(T), len(df_))
        return df_

def SequenceRdn(df):
    '''With this function, we randomize the order in which snapshots appear'''
    df_ = copy(df)
    t_orig = np.unique(df_.t.values)
    t_shuffled = copy(t_orig)
    np.random.shuffle(t_shuffled)
    Mapper = dict(zip(t_orig, t_shuffled))
    df_.t = df_.t.map(lambda x: Mapper[x])
    return df_

# %%
# load dataset
df = pd.read_csv('Data/primaryschool.csv')

# initialize the Data class
Data = Graphs4Distance(verbose = 1)

samples = 250
names = []

# run the experiment
for i in range(samples):
    print(f'{i+1}/{samples}', end = '\r')

    df_ = TimeRdn(df) # create a randomization with the TimeRdn function
    Data.LoadDataset(df_, f'time_{i}', t_agg = 600) # load the sataset
    Data.GraphDynamicEmbedding(f'time_{i}') # create the embedding. By running this command the new dataset is immediately removed from memory, to save space
    names.append(f'time_{i}')

    df_ = SequenceRdn(df) # repeat the operation with the SequenceRdn function
    Data.LoadDataset(df_, f'sequence_{i}', t_agg = 600)
    Data.GraphDynamicEmbedding(f'sequence_{i}')
    names.append(f'sequence_{i}')

# build the distance matrix
D = np.zeros((2*samples, 2*samples))
names = np.sort(names)

for i in range(2*samples):
    for j in range(2*samples):
        D[i,j] = Data.GetDistance(names[i], names[j]) # we compute the unmatched distance between graph pairs
# Out:
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_0
# Deleting time_0
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_0
# Deleting sequence_0
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_1
# Deleting time_1
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_1
# Deleting sequence_1
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_2
# Deleting time_2
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_2
# Deleting sequence_2
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_3
# Deleting time_3
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_3
# Deleting sequence_3
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_4
# Deleting time_4
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_4
# Deleting sequence_4
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_123
# Deleting time_123
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_123
# Deleting sequence_123
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_124
# Deleting time_124
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_124
# Deleting sequence_124
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_125
# Deleting time_125
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_125
# Deleting sequence_125
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_126
# Deleting time_126
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_126
# Deleting sequence_126
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_127
# Deleting time_127
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_127
# Deleting sequence_127
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_128
# Deleting time_128
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_128
# Deleting sequence_128
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_129
# Deleting time_129
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_129
# Deleting sequence_129
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_130
# Deleting time_130
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_130
# Deleting sequence_130
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_131
# Deleting time_131
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_131
# Deleting sequence_131
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_132
# Deleting time_132
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_132
# Deleting sequence_132
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_133
# Deleting time_133
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_133
# Deleting sequence_133
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_134
# Deleting time_134
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_134
# Deleting sequence_134
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_135
# Deleting time_135
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_135
# Deleting sequence_135
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_136
# Deleting time_136
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_136
# Deleting sequence_136
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_137
# Deleting time_137
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_137
# Deleting sequence_137
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_138
# Deleting time_138
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_138
# Deleting sequence_138
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_139
# Deleting time_139
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_139
# Deleting sequence_139
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_140
# Deleting time_140
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_140
# Deleting sequence_140
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_141
# Deleting time_141
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_141
# Deleting sequence_141
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_142
# Deleting time_142
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_142
# Deleting sequence_142
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_143
# Deleting time_143
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_143
# Deleting sequence_143
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_144
# Deleting time_144
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_144
# Deleting sequence_144
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_145
# Deleting time_145
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_145
# Deleting sequence_145
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_146
# Deleting time_146
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_146
# Deleting sequence_146
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_147
# Deleting time_147
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_147
# Deleting sequence_147
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_148
# Deleting time_148
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_148
# Deleting sequence_148
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_149
# Deleting time_149
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_149
# Deleting sequence_149
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_150
# Deleting time_150
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_150
# Deleting sequence_150
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_151
# Deleting time_151
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_151
# Deleting sequence_151
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_152
# Deleting time_152
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_152
# Deleting sequence_152
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_153
# Deleting time_153
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_153
# Deleting sequence_153
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_154
# Deleting time_154
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_154
# Deleting sequence_154
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_155
# Deleting time_155
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_155
# Deleting sequence_155
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_156
# Deleting time_156
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_156
# Deleting sequence_156
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_157
# Deleting time_157
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_157
# Deleting sequence_157
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_158
# Deleting time_158
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_158
# Deleting sequence_158
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_159
# Deleting time_159
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_159
# Deleting sequence_159
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_160
# Deleting time_160
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_160
# Deleting sequence_160
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_161
# Deleting time_161
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_161
# Deleting sequence_161
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_162
# Deleting time_162
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_162
# Deleting sequence_162
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_163
# Deleting time_163
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_163
# Deleting sequence_163
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_164
# Deleting time_164
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_164
# Deleting sequence_164
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_165
# Deleting time_165
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_165
# Deleting sequence_165
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_166
# Deleting time_166
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_166
# Deleting sequence_166
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_167
# Deleting time_167
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_167
# Deleting sequence_167
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_168
# Deleting time_168
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_168
# Deleting sequence_168
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_169
# Deleting time_169
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_169
# Deleting sequence_169
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_170
# Deleting time_170
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_170
# Deleting sequence_170
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_171
# Deleting time_171
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_171
# Deleting sequence_171
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_172
# Deleting time_172
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_172
# Deleting sequence_172
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_173
# Deleting time_173
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_173
# Deleting sequence_173
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_174
# Deleting time_174
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_174
# Deleting sequence_174
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_175
# Deleting time_175
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_175
# Deleting sequence_175
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_176
# Deleting time_176
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_176
# Deleting sequence_176
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_177
# Deleting time_177
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_177
# Deleting sequence_177
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_178
# Deleting time_178
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_178
# Deleting sequence_178
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_179
# Deleting time_179
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_179
# Deleting sequence_179
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_180
# Deleting time_180
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_180
# Deleting sequence_180
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_181
# Deleting time_181
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_181
# Deleting sequence_181
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_182
# Deleting time_182
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_182
# Deleting sequence_182
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_183
# Deleting time_183
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_183
# Deleting sequence_183
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_184
# Deleting time_184
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_184
# Deleting sequence_184
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_185
# Deleting time_185
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_185
# Deleting sequence_185
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_186
# Deleting time_186
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_186
# Deleting sequence_186
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_187
# Deleting time_187
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_187
# Deleting sequence_187
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_188
# Deleting time_188
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_188
# Deleting sequence_188
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_189
# Deleting time_189
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_189
# Deleting sequence_189
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_190
# Deleting time_190
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_190
# Deleting sequence_190
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_191
# Deleting time_191
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_191
# Deleting sequence_191
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_192
# Deleting time_192
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_192
# Deleting sequence_192
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_193
# Deleting time_193
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_193
# Deleting sequence_193
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_194
# Deleting time_194
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_194
# Deleting sequence_194
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_195
# Deleting time_195
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_195
# Deleting sequence_195
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_196
# Deleting time_196
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_196
# Deleting sequence_196
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_197
# Deleting time_197
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_197
# Deleting sequence_197
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_198
# Deleting time_198
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_198
# Deleting sequence_198
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_199
# Deleting time_199
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_199
# Deleting sequence_199
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_200
# Deleting time_200
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_200
# Deleting sequence_200
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_201
# Deleting time_201
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_201
# Deleting sequence_201
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_202
# Deleting time_202
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_202
# Deleting sequence_202
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_203
# Deleting time_203
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_203
# Deleting sequence_203
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_204
# Deleting time_204
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_204
# Deleting sequence_204
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_205
# Deleting time_205
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_205
# Deleting sequence_205
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_206
# Deleting time_206
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_206
# Deleting sequence_206
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_207
# Deleting time_207
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_207
# Deleting sequence_207
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_208
# Deleting time_208
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_208
# Deleting sequence_208
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_209
# Deleting time_209
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_209
# Deleting sequence_209
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_210
# Deleting time_210
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_210
# Deleting sequence_210
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_211
# Deleting time_211
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_211
# Deleting sequence_211
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_212
# Deleting time_212
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_212
# Deleting sequence_212
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_213
# Deleting time_213
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_213
# Deleting sequence_213
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_214
# Deleting time_214
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_214
# Deleting sequence_214
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_215
# Deleting time_215
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_215
# Deleting sequence_215
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_216
# Deleting time_216
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_216
# Deleting sequence_216
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_217
# Deleting time_217
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_217
# Deleting sequence_217
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_218
# Deleting time_218
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_218
# Deleting sequence_218
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_219
# Deleting time_219
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_219
# Deleting sequence_219
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_220
# Deleting time_220
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_220
# Deleting sequence_220
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_221
# Deleting time_221
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_221
# Deleting sequence_221
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_222
# Deleting time_222
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_222
# Deleting sequence_222
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_223
# Deleting time_223
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_223
# Deleting sequence_223
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_224
# Deleting time_224
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_224
# Deleting sequence_224
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_225
# Deleting time_225
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_225
# Deleting sequence_225
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_226
# Deleting time_226
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_226
# Deleting sequence_226
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_227
# Deleting time_227
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_227
# Deleting sequence_227
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_228
# Deleting time_228
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_228
# Deleting sequence_228
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_229
# Deleting time_229
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_229
# Deleting sequence_229
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_230
# Deleting time_230
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_230
# Deleting sequence_230
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_231
# Deleting time_231
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_231
# Deleting sequence_231
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_232
# Deleting time_232
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_232
# Deleting sequence_232
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_233
# Deleting time_233
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_233
# Deleting sequence_233
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_234
# Deleting time_234
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_234
# Deleting sequence_234
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_235
# Deleting time_235
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_235
# Deleting sequence_235
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_236
# Deleting time_236
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_236
# Deleting sequence_236
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_237
# Deleting time_237
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_237
# Deleting sequence_237
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_238
# Deleting time_238
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_238
# Deleting sequence_238
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_239
# Deleting time_239
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_239
# Deleting sequence_239
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_240
# Deleting time_240
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_240
# Deleting sequence_240
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_241
# Deleting time_241
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_241
# Deleting sequence_241
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_242
# Deleting time_242
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_242
# Deleting sequence_242
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_243
# Deleting time_243
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_243
# Deleting sequence_243
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_244
# Deleting time_244
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_244
# Deleting sequence_244
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_245
# Deleting time_245
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_245
# Deleting sequence_245
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_246
# Deleting time_246
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_246
# Deleting sequence_246
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_247
# Deleting time_247
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_247
# Deleting sequence_247
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_248
# Deleting time_248
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_248
# Deleting sequence_248
# The graph has n = 242 nodes
# The number of snapshot is T = 247.
# Computing the embeddings of time_249
# Deleting time_249
# The graph has n = 242 nodes
# The number of snapshot is T = 195.
# Computing the embeddings of sequence_249
# Deleting sequence_249

# %%
# get the 2D embedding from the distance matrix with umap and plot
Xembedded_umap = umap.UMAP(metric = 'precomputed').fit_transform(D)

plt.figure(figsize = (5, 5))
plt.scatter(Xembedded_umap[:,0][:samples], Xembedded_umap[:,1][:samples], marker = 'o', s = 60, color = '#c1121f', alpha = 0.3, label = 'Sequence shuffling')
plt.scatter(Xembedded_umap[:,0][samples:], Xembedded_umap[:,1][samples:], marker = 'd', s = 60, color = '#669bbc', alpha = 0.3, label = 'Time shuffling')
plt.legend(fontsize = 14)
plt.xticks([])
plt.yticks([])
plt.show();
# Out:
# /home/lorenzo/anaconda3/lib/python3.12/site-packages/umap/umap_.py:1865: UserWarning: using precomputed metric; inverse_transform will be unavailable
#   warn("using precomputed metric; inverse_transform will be unavailable")

# %% [markdown]
# ## Recognizing a partial shuffling with the matched distance
#
# We now test the matched distance by looking at its sensitivity to partial node relabeling. We always consider the same temporal graph and randomize the labels of a fraction $\alpha$ of its nodes. We then compute the distance between the original and reshuffled graph. The experiment is averaged over $10$ randomizations and, as we show below, the matched distance rapidly grows with $\alpha$, meaning that the matched distance between graph pairs can distinguish two graphs that only differ by the naming of their nodes.

# %%
def PartialNodeShuffling(df, alpha):
    '''With this function we partially shuffle the nodes labels of the temporal graph'''

    df_ = copy(df)

    all_nodes = np.unique(df[['i', 'j']])
    n = len(all_nodes)
    idx = np.random.binomial(1, alpha, n) == 1
    all_nodes_shuffled = copy(all_nodes)
    to_be_shuffled = all_nodes_shuffled[idx]
    np.random.shuffle(to_be_shuffled)
    all_nodes_shuffled[idx] = to_be_shuffled
    NodeMapper = dict(zip(all_nodes, all_nodes_shuffled))

    df_.i = df_.i.map(lambda x: NodeMapper[x])
    df_.j = df_.j.map(lambda x: NodeMapper[x])

    return df_

# %%
# load dataset
df = pd.read_csv('Data/primaryschool.csv')

# initialize the Data class
Data = Graphs4Distance(verbose = 0)

Data.LoadDataset(df, 'original', t_agg = 600) # load the sataset

alphav = np.linspace(0,1,10)
n_randomization = 10

for i in range(n_randomization):
    print(f'i:{i+1}/{n_randomization}', end = '\r')
    for alpha in alphav:
        df_ = PartialNodeShuffling(df, alpha)
        Data.LoadDataset(df_, f'alpha_{alpha}_{i}', t_agg = 600) # load the sataset
        Data.GraphDynamicEmbedding(f'alpha_{alpha}_{i}') # create the embedding. By running this command the new dataset is immediately removed from memory, to save space
# Out:
# i:10/10

# %%
plt.figure(figsize = (6, 4))
plt.plot(alphav, [np.mean([Data.GetDistance('original', f'alpha_{alpha}_{i}', distance_type = 'matched', node_mapping = 'Same') for i in range(n_randomization)]) for alpha in alphav], marker = 'o', color = 'dodgerblue', alpha = 0.8)
plt.xlabel(r'$\alpha$', fontsize = 20)
plt.ylabel(r'$d_{\rm m}$', fontsize = 20)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.show();
